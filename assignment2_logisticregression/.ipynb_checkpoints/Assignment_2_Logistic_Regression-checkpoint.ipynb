# %%
import pandas as pd
import urllib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import os
import numpy as np
from operator import itemgetter
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
# requirements : 
#     recommended platform : ubuntu
#     python == 3.7
#     pip install pandas
#     pip install numpy
#     pip install sklearn
#     pip install seaborn
#     pip install matplotlib
# %matplotlib inline

# %% [markdown]
# **Why import os?**
#
# This module provides a portable way of using operating system dependent functionality. If you just want to read or write a file see open(), if you want to manipulate paths, see the os.path module, and if you want to read all the lines in all the files on the command line see the fileinput module. For creating temporary files and directories see the tempfile module, and for high-level file and directory handling see the shutil module.

# %% [markdown]
# # DATASET
# Data Source
#
#     https://archive.ics.uci.edu/ml/datasets/Skin+Segmentation
#
#     Source:
#     Rajen Bhatt, Abhinav Dhall, rajen.bhatt '@' gmail.com, IIT Delhi.
#
#     Data Set Information:
#
#         The skin dataset is collected by randomly sampling B,G,R values from face images of various age groups (young, middle, and old), race groups (white, black, and asian), and genders obtained from FERET database and PAL database. Total learning sample size is 245057; out of which 50859 is the skin samples and 194198 is non-skin samples.
#
#     Attribute Information:
#
#         This dataset is of the dimension 245057 * 4 where first three columns are B,G,R (x1,x2, and x3 features) values and fourth column is of the class labels (decision variable y).
#
#     Relevant Papers:
#
#
# 1. Rajen B. Bhatt, Gaurav Sharma, Abhinav Dhall, Santanu Chaudhury, â€œEfficient skin region segmentation using low complexity fuzzy decision tree modelâ€, IEEE-INDICON 2009, Dec 16-18, Ahmedabad, India, pp. 1-4.
#         2. Abhinav Dhall, Gaurav Sharma, Rajen Bhatt, Ghulam Mohiuddin Khan, â€œAdaptive Digital Makeupâ€, in Proc. of International Symposium on Visual Computing (ISVC) 2009, Nov. 30 â€“ Dec. 02, Las Vegas, Nevada, USA, Lecture Notes in Computer Science, Vol. 5876, pp. 728-736.
#
#
#
#         Citation Request:
#
#         Rajen Bhatt, Abhinav Dhall, 'Skin Segmentation Dataset', UCI Machine Learning Repository

# %% [markdown]
# ### DOWNLOAD DATASET
#     Direct Link : https://archive.ics.uci.edu/ml/machine-learning-databases/00229/Skin_NonSkin.txt

# %% [markdown]
# #### DOWNLOAD USING PYTHON

# %%
if not os.path.exists('./Skin_NonSkin.txt'):
    url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00229/Skin_NonSkin.txt'
    urllib.request.urlretrieve(url,'./Skin_NonSkin.txt')

# %% [markdown]
# #### Read using pandas

# %%
df = pd.read_csv('Skin_NonSkin.txt', sep='\t',names =['B','G','R','skin'])
df.head()
# Out:
#     B   G    R  skin
# 0  74  85  123     1
# 1  73  84  122     1
# 2  72  83  121     1
# 3  70  81  119     1
# 4  70  81  119     1

# %% [markdown]
# #### Check Missing values

# %% [markdown]
# **dataframe.isna()**
#
# Pandas dataframe.isna() function is used to detect missing values. It return a boolean same-sized object indicating if the values are NA. NA values, such as None or numpy.NaN, gets mapped to True values. Everything else gets mapped to False values. Characters such as empty strings ” or numpy.inf are not considered NA values (unless you set pandas.options.mode.use_inf_as_na = True).

# %% [markdown]
# ### Standardize dataset

# %% [markdown]
# **Why Standardize?**
#
# It is another integral preprocessing step.In Standardization we transform our values such that the mean of the values is 0 and the standard deviation is 1. So in simple terms we just calculate the mean and standard deviation of the values and then for each data point we just subtract the mean and divide it by standard deviation.
# Which algorithms? (YES: Regression and Classification problems, NO: Trees) Linear Regression (convergence in GD will happen more quickly, allows random initialized coefficients to be closer to global minimum).; wherever Gradient Descent employed; k means clustering (Euclid dist), k nearest neighbor (Euclid dist); not necessary for Decision Trees, Random Forest, Xgboost
#
# **How?**
#
# 1. Subtract Mean (Zero Out): mu = 1/m summation vector x from i to m and x:= x - mu for every training sample (so just moved training sample until has zero mean)
# 2. Normalize the variances: a vector sigma^2 = 1/m summation vector x **2 element-wise squaring from i to m   and x /= sigma^2 for each
#
# z-score: a measure of how many std dev an observation is away from mean
# Z = (X - mu)/sigma
#
# from normal dist X ---> Z stardard normal random variable

# %%
df.skin.unique()
# Out:
# array([1, 2])

# %%
feature = df[df.columns[~df.columns.isin(['skin'])]] #Except Label
label = (df[['skin']] == 1)*1 #Converting to 0 and 1 (this col has values 1 and 2) if value =1, then True, else false =0. Example of code golf; trying to achieve shortest length of code possible.
feature = feature / 255. #Pixel values range from 0-255 converting between 0-1

# %%
print (label)
# Out:
#         skin
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 245052     0
# 245053     0
# 245054     0
# 245055     0
# 245056     0
#
# [245057 rows x 1 columns]

# %%
#golfless = (df[['skin']] == 1)
#golfless = golfless.astype(int)
#print(golfless)

# %%
#df['skin'].replace([1,2],[1,0],inplace=True)
#df.skin.unique()

# %%
feature.head()
# Out:
#           B         G         R
# 0  0.290196  0.333333  0.482353
# 1  0.286275  0.329412  0.478431
# 2  0.282353  0.325490  0.474510
# 3  0.274510  0.317647  0.466667
# 4  0.274510  0.317647  0.466667

# %%
label.head()
# Out:
#    skin
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %% [markdown]
# ### Explore your data
#     Please try to understand the nature of data

# %%
alldf = pd.concat([feature,label], sort=True, axis=1)
alldf
# Out:
#                B         G         R  skin
# 0       0.290196  0.333333  0.482353     1
# 1       0.286275  0.329412  0.478431     1
# 2       0.282353  0.325490  0.474510     1
# 3       0.274510  0.317647  0.466667     1
# 4       0.274510  0.317647  0.466667     1
# ...          ...       ...       ...   ...
# 245052  0.639216  0.635294  0.439216     0
# 245053  0.639216  0.635294  0.439216     0
# 245054  0.639216  0.635294  0.439216     0
# 245055  0.639216  0.635294  0.439216     0
# 245056  1.000000  1.000000  1.000000     0
#
# [245057 rows x 4 columns]

# %% [markdown]
# Heatmap Visualize which variables are correlated to each other on scale of 0 to 1

# %%
plt.figure(figsize=(10,5))
sns.heatmap(alldf.corr(),annot=True, linewidth = 0.5)

# %% [markdown]
# Pandas sample() is used to generate a sample random row or column from the function caller data frame.

# %%
sample = alldf.sample(1000)

# %%
onlybgr = sample[sample.columns[~sample.columns.isin(['skin'])]]

# %% [markdown]
# Seaborn pairplot()
# Plot pairwise relationships in a dataset. The pairs plot builds on two basic figures, the histogram and the scatter plot. The histogram on the diagonal allows us to see the distribution of a single variable while the scatter plots on the upper and lower triangles show the relationship (or lack thereof) between two variables.
# By default, this function will create a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column. The diagonal Axes are treated differently, drawing a plot to show the univariate distribution of the data for the variable in that column.
#
# hue: Variable in data to map plot aspects to different colors; coloring the figures based on a categorical variable
# kind: Kind of plot for the non-identity relationships {scatter, reg} add scatter or regression

# %%
sns.pairplot(onlybgr)

# %%
sample_ = sample.copy()
sample_['skin'] = sample.skin.apply(lambda x:{1:'skin',0:'not skin'}.get(x))
sns.pairplot(sample_, hue="skin")
# sample

# %%
sns.pairplot(onlybgr, kind="reg")

# %%
# Lets see how many 0s and 1s
(label == 0).skin.sum(),(label == 1).skin.sum()
# Out:
# (194198, 50859)

# %% [markdown]
# *Cross Validation?**
#
# A resampling procedure used to evaluate machine learning models on a limited data sample. The procedure has a single parameter called k that refers to the number of groups that a given data sample is to be split into.

# %% [markdown]
# ## SPLIT DATA INTO 5 CROSS - VALIDATION
# cross validation to avoid overfitting
# - leave one out cv (LOOCV), leads to low bias (accuracy down, error rate increase when deploy model to production); not used lately
# - K-Folds CV, used due to random_state changing train and test sets in train_test_split
# where k =5 means 5 experiements. decides what should be test data based on k. Experiment 1 of 5 | Accuracy 1 of 5
#
#
# It’s very similar to train/test split, but it’s applied to more subsets. Meaning, we split our data into k subsets, and train on k-1 one of those subset. What we do is to hold the last subset for test

# %%
x = feature.values
y = label.values

# %% [markdown]
# Scikit train_test_split(): split dataset into training and datset randomly.
#
# We split this into two different datasets, one for the independent features — x, and one for the dependent variable — y (which is the last column). We’ll now split the dataset x into two separate sets — xTrain and xTest. Similarly, we’ll split the dataset y into two sets as well — yTrain and yTest. Doing this using the sklearn library is very simple. The training set contains a known output and the model learns on this data in order to be generalized to other data later on. We have the test dataset (or subset) in order to test our model’s prediction on this subset.
# test_size = 20% then train_set=80%
# random_state = if non-zero ensure reproducibility; an guarantee that the output of Run 1 will be equal to the output of Run 2. Used for initializing the internal random number generator, which will decide the splitting of data into train and test indices in your case.

# %%
# We will keep fix test and take 5 cross validation set
# so we will have five different data set
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.20, random_state=1)

# %%
#Lets see the size of xtrain, xtest
len(xtrain),len(xtest)
# Out:
# (196045, 49012)

# %%
# 5 Fold Split
# First merge xtrain and ytrain so that we can easily divide into 5 chunks

data = np.concatenate([xtrain,ytrain],axis = 1)
# Observe the shape of array
xtrain.shape,ytrain.shape,data.shape
# Out:
# ((196045, 3), (196045, 1), (196045, 4))

# %%
# Divide our data to 5 chunks
chunks = np.split(data,5)

# %%
datadict = {'fold1':{'train':{'x':None,'y':None},'val':{'x':None,'y':None},'test':{'x':xtest,'y':ytest}},
            'fold2':{'train':{'x':None,'y':None},'val':{'x':None,'y':None},'test':{'x':xtest,'y':ytest}},
            'fold3':{'train':{'x':None,'y':None},'val':{'x':None,'y':None},'test':{'x':xtest,'y':ytest}}, 
            'fold4':{'train':{'x':None,'y':None},'val':{'x':None,'y':None},'test':{'x':xtest,'y':ytest}},
            'fold5':{'train':{'x':None,'y':None},'val':{'x':None,'y':None},'test':{'x':xtest,'y':ytest}},}

# %%
for i in range(5):
    datadict['fold'+str(i+1)]['val']['x'] = chunks[i][:,0:3]
    datadict['fold'+str(i+1)]['val']['y'] = chunks[i][:,3:4]
    
    idx = list(set(range(5))-set([i]))
    X = np.concatenate(itemgetter(*idx)(chunks),0)
    datadict['fold'+str(i+1)]['train']['x'] = X[:,0:3]
    datadict['fold'+str(i+1)]['train']['y'] = X[:,3:4]

# %%
def writepickle(data, filename):
    with open(filename, 'wb') as f:
        pickle.dump(data, f)

def readpickle(filename):
    with open(filename, 'rb') as f:
        data = pickle.load(f)
    return data

# %%
writepickle(datadict,'data.pkl')

# %%
writepickle(datadict,'data.pkl')

# %% [markdown]
# ## Now You Can Read This Pickle File And Use In Your Project

# %%
data = readpickle('data.pkl')

# %% [markdown]
# ## How to access data
#     Example : Access fold1 data

# %%
fold1 = data['fold1']
fold1_train = fold1['train']
fold1_val = fold1['val']
fold1_test = fold1['test']

xtrain, ytrain = fold1_train['x'],fold1_train['y']
xval, yval = fold1_val['x'], fold1_val['y']
xtest, ytest = fold1_test['x'],fold1_test['y']

# %%
xtrain.shape, ytrain.shape
# Out:
# ((156836, 3), (156836, 1))

# %%
xval.shape, yval.shape
# Out:
# ((39209, 3), (39209, 1))

# %%
xtest.shape,ytest.shape
# Out:
# ((49012, 3), (49012, 1))

# %% [markdown]
# <h1 style="color:green">!!!!!!!!!! NOTES !!!!!!!!!!</h1>
#
#     This walkthrough is just to make your life easier
#     If you want to use your own ways of doing data processing it is fine
#     You can continue your assignment right-away from below or setup
#     a project like assignment 1. You can use any library you want

# %% [markdown]
# # Implementation
# 1. define independent(X) and dependent(y_pred) variables
# 2. split data into train and test sets
# 3. standardize data
#
# 4. create model instance : LogReg = LogisticRegression()
# 5. fit model: LogReg.fit(xtrain, ytrain)
# 6. make prediction: y_pred = LogReg.predict(xtest)
# 7. evaluate performance (a and/or b):
#       a. accuracy_score(ytest,y_pred)
#       b. classification report

# %% [markdown]
# # Data Science Project Pipelines of Machine Learning Use Case
#
# 1. Data Gathering
# 2. Feature Engineering
# 3. Feature Selection
# 4. Model Creation
# 5. Model Deployment

# %% [markdown]
# # Classification Metrics
#     accuracy_score
#     auc
#     average_precision_score
#     brier_score_loss
#     cohen_kappa_score
#     dcg_score
#     fbeta_score
#     hamming_loss
#     hinge_loss
#     jaccard_similarity_score
#     log_loss
#     matthews_corrcoef
#     ndcg_score
#     precision_recall_curve
#     precision_recall_fscore_support
#     roc_auc_score
#     roc_curve
#     zero_one_loss

# %% [markdown]
# # Fit Model on Training Set 1

# %%
LogReg = LogisticRegression(solver='lbfgs')
LogReg_Train = LogReg.fit(xtrain, ytrain.ravel())
print(LogReg.score(xtrain, ytrain.ravel()))
# Out:
# 0.9188834196230458

# %% [markdown]
# # Accuracy of Logistic Regression on Test Set

# %%
y_pred = LogReg.predict(xtest)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(LogReg.score(xtest, ytest)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.92

# %% [markdown]
# # Accuracy
# Confusion Matrix:
#      PN | PY
# AN
# AY

# %%
confusion_matrix(ytest,y_pred)
# Out:
# array([[36488,  2239],
#        [ 1736,  8549]])

# %%
accuracy_score(ytest,y_pred)
# Out:
# 0.9188974128784787

# %% [markdown]
# # Classification Report
# Compute precision, recall, F-measure and support

# %%
print(classification_report(ytest, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     38727
#            1       0.79      0.83      0.81     10285
#
#     accuracy                           0.92     49012
#    macro avg       0.87      0.89      0.88     49012
# weighted avg       0.92      0.92      0.92     49012

# %%
val1 = "Hey"
val2 = "There"

print("_____________________________________________")
print ("{0:10}| {1}".format(" ","ACCURACY"))
print ("{0:10}| {1:10} {2:10}".format("FOLD", "VAL", "TEST"))
# Out:
# _____________________________________________
#           | ACCURACY
# FOLD      | VAL        TEST

# %% [markdown]
# # Generate Validation and Testing Accuracy

# %%
print("_____________________________________________")
print ("{0:8}| {1}".format(" ","ACCURACY"))
print ("{0:8}| {1:10} | {2:}".format("FOLD", "VAL", "TEST"))

valAverage =0
testAverage =0
valSum=0
testSum=0

for i in range(5):
    
    fold = data['fold'+str(i+1)]
    fold_train = fold['train']
    fold_val = fold['val']
    fold_test = fold['test']

    xtrain, ytrain = fold_train['x'],fold_train['y']
    xval, yval = fold_val['x'], fold_val['y']
    xtest, ytest = fold_test['x'],fold_test['y']
        
    LogReg = LogisticRegression(solver='lbfgs')
    LogReg_Val = LogReg.fit(xval, yval.ravel())
    LogReg_Val_Score = LogReg_Val.score(xval, yval.ravel())
    
    LogRegTest = LogisticRegression(solver='lbfgs')
    y_pred = LogReg.predict(xtest)
    LogReg_Test = LogRegTest.fit(ytest,y_pred.ravel())
    LogReg_Test_Score = LogReg_Test.score(ytest, y_pred.ravel())
    
    valSum+=LogReg_Val_Score
    testSum+=LogReg_Test_Score
    
    print ("{0:0}       | {1:0.4f}     | {2:0.4f}".format(i+1, LogReg_Val_Score, LogReg_Test_Score))
  
 
valAverage = valSum/5
testAverage = testSum/5    

    
print("_____________________________________________")
print ("{0}     | {1:0.4f}     | {2:0.4f}".format("AVG", valAverage, testAverage))
# Out:
# _____________________________________________
#         | ACCURACY
# FOLD    | VAL        | TEST
# 1       | 0.9187     | 0.9188
# 2       | 0.9180     | 0.9192
# 3       | 0.9210     | 0.9199
# 4       | 0.9171     | 0.9178
# 5       | 0.9190     | 0.9184
# _____________________________________________
# AVG     | 0.9188     | 0.9188

# %%
fold1 = data['fold1']
fold2 = data['fold2']
fold3 = data['fold3']
fold4 = data['fold4']
fold5 = data['fold5']

fold1_train = fold1['train']
fold1_val = fold1['val']
fold1_test = fold1['test']

fold2_train = fold2['train']
fold2_val = fold2['val']
fold2_test = fold2['test']

fold3_train = fold3['train']
fold3_val = fold3['val']
fold3_test = fold3['test']

fold4_train = fold4['train']
fold4_val = fold4['val']
fold4_test = fold4['test']

fold5_train = fold5['train']
fold5_val = fold5['val']
fold5_test = fold5['test']

xtrain1, ytrain1 = fold1_train['x'],fold1_train['y']
xval1, yval1 = fold1_val['x'], fold1_val['y']
xtest1, ytest1 = fold1_test['x'],fold1_test['y']

xtrain2, ytrain2 = fold2_train['x'],fold2_train['y']
xval2, yval2 = fold2_val['x'], fold2_val['y']
xtest2, ytest2 = fold2_test['x'],fold2_test['y']

xtrain3, ytrain3 = fold3_train['x'],fold3_train['y']
xval3, yval3 = fold3_val['x'], fold3_val['y']
xtest3, ytest3 = fold3_test['x'],fold3_test['y']

xtrain4, ytrain4 = fold4_train['x'],fold4_train['y']
xval4, yval4 = fold4_val['x'], fold4_val['y']
xtest4, ytest4 = fold4_test['x'],fold4_test['y']

xtrain5, ytrain5 = fold5_train['x'],fold5_train['y']
xval5, yval5 = fold5_val['x'], fold5_val['y']
xtest5, ytest5 = fold5_test['x'],fold5_test['y']

LogReg = LogisticRegression(solver='lbfgs')
    
LogReg_Val1 = LogReg.fit(xval1, yval1.ravel())
LogReg_Val1_Score = LogReg_Val1.score(xval1, yval1.ravel())

LogReg_Val2 = LogReg.fit(xval2, yval2.ravel())
LogReg_Val2_Score = LogReg_Val2.score(xval2, yval2.ravel())

LogReg_Val3 = LogReg.fit(xval3, yval3.ravel())
LogReg_Val3_Score = LogReg_Val3.score(xval3, yval3.ravel())

LogReg_Val4 = LogReg.fit(xval4, yval4.ravel())
LogReg_Val4_Score = LogReg_Val4.score(xval4, yval4.ravel())

LogReg_Val5 = LogReg.fit(xval5, yval5.ravel())
LogReg_Val5_Score = LogReg_Val5.score(xval5, yval5.ravel())


LogRegTest = LogisticRegression(solver='lbfgs')

y_pred1 = LogReg.predict(xtest)
LogReg_Test1 = LogRegTest.fit(ytest1,y_pred1.ravel())
LogReg_Test1_Score = LogReg_Test1.score(ytest1, y_pred1.ravel())

y_pred2 = LogReg.predict(xtest)
LogReg_Test2 = LogRegTest.fit(ytest2,y_pred2.ravel())
LogReg_Test2_Score = LogReg_Test2.score(ytest2, y_pred2.ravel())

y_pred3 = LogReg.predict(xtest)
LogReg_Test3 = LogRegTest.fit(ytest3,y_pred3.ravel())
LogReg_Test3_Score = LogReg_Test3.score(ytest3, y_pred3.ravel())

y_pred4 = LogReg.predict(xtest)
LogReg_Test4 = LogRegTest.fit(ytest4,y_pred4.ravel())
LogReg_Test4_Score = LogReg_Test4.score(ytest4, y_pred4.ravel())

y_pred5 = LogReg.predict(xtest)
LogReg_Test5 = LogRegTest.fit(ytest5,y_pred5.ravel())
LogReg_Test5_Score = LogReg_Test5.score(ytest5, y_pred5.ravel())

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

Log_roc_auc1 = roc_auc_score(ytest1, LogReg.predict(xtest1))
frp1, tpr1, threshold=roc_curve(ytest1, LogReg.predict(xtest1))

Log_roc_auc2 = roc_auc_score(ytest2, LogReg.predict(xtest2))
frp2, tpr2, threshold=roc_curve(ytest2, LogReg.predict(xtest2))

Log_roc_auc3 = roc_auc_score(ytest3, LogReg.predict(xtest3))
frp3, tpr3, threshold=roc_curve(ytest3, LogReg.predict(xtest3))

Log_roc_auc4 = roc_auc_score(ytest4, LogReg.predict(xtest4))
frp4, tpr4, threshold=roc_curve(ytest4, LogReg.predict(xtest4))

Log_roc_auc5 = roc_auc_score(ytest5, LogReg.predict(xtest5))
frp5, tpr5, threshold=roc_curve(ytest5, LogReg.predict(xtest5))

# %% [markdown]
# Area under curve is 89% of results. Able to capture 89% of the positives that will be classfied correctly. The receiver operating characteristic (ROC) curve is a two dimensional graph in which the false positive rate is plotted on the X axis and the true positive rate is plotted on the Y axis. The ROC curves are useful to visualize and compare the performance of classifier methods.

# %%
plt.figure()
plt.plot(frp1, tpr1, label="Logit Model 1(area=%0.2f)" % Log_roc_auc1)
plt.plot(frp2, tpr2, label="Logit Model 2(area=%0.2f)" % Log_roc_auc2)
plt.plot(frp3, tpr3, label="Logit Model 3(area=%0.2f)" % Log_roc_auc3)
plt.plot(frp4, tpr4, label="Logit Model 4(area=%0.2f)" % Log_roc_auc4)
plt.plot(frp5, tpr5, label="Logit Model 5(area=%0.2f)" % Log_roc_auc5)

plt.title("Receiver Operating Characteristic (Validation)")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.plot([0,1],[0,1],'r--')
plt.xlim(-0.05,1.05)
plt.ylim(-0.05,1.05)
plt.savefig("Log_ROC")
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
Log_roc_auc = roc_auc_score(ytest, LogReg.predict(xtest))
frp, tpr, threshold=roc_curve(ytest, LogReg.predict(xtest))

# %%
plt.figure()
plt.plot(frp, tpr, label="Logit Model 1(area=%0.2f)" % Log_roc_auc)
plt.title("Receiver Operating Characteristic (Test)")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.plot([0,1],[0,1],'r--')
plt.xlim(-0.05,1.05)
plt.ylim(-0.05,1.05)
plt.savefig("Log_ROC")
plt.show()

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_predict
x = feature.values
y = label.values

model = linear_model.LogisticRegression(solver="lbfgs")
predicted = cross_val_predict(model,x,y.ravel(),cv=5)

# %% [markdown]
# # Visualizing the Result

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.scatter(y,predicted, edgecolors=(0,0,0))
ax.plot([y.min(),y.max()],[y.min(),y.max()], 'k--',lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# %%
alldf.head(10)
# Out:
#           B         G         R  skin
# 0  0.290196  0.333333  0.482353     1
# 1  0.286275  0.329412  0.478431     1
# 2  0.282353  0.325490  0.474510     1
# 3  0.274510  0.317647  0.466667     1
# 4  0.274510  0.317647  0.466667     1
# 5  0.270588  0.313725  0.462745     1
# 6  0.274510  0.317647  0.466667     1
# 7  0.274510  0.317647  0.466667     1
# 8  0.298039  0.341176  0.490196     1
# 9  0.298039  0.341176  0.490196     1

# %%
#boston = datasets.load_boston()
# print(boston)

y = alldf.skin
model=linear_model.LogisticRegression()
print(y)

from sklearn.model_selection import cross_val_predict

predicted = cross_val_predict(model, alldf, y, cv=10)



import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 245052    0
# 245053    0
# 245054    0
# 245055    0
# 245056    0
# Name: skin, Length: 245057, dtype: int64
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from timeit import default_timer as timer
from matplotlib import pyplot as plt
# store data as an array
X = np.array(alldf)
y = alldf.skin

# again, timing the function for comparison
start_kfold = timer()


k_predictions = cross_val_predict(lm, X, y, cv=5)
print(k_predictions)
end_kfold = timer()
kfold_time = (end_kfold - start_kfold)

# plot k-fold predictions against actual
plot_k = sns.scatterplot(y, k_predictions)
plot_k.set(xlabel='Given', ylabel='Prediction')# generate and graph y = x line
x_plot = np.linspace(0,5,100)
y_plot = x_plot
plt.plot(x_plot, y_plot, color='r')
# Out:
# [ 1.00000000e+00  1.00000000e+00  1.00000000e+00 ... -2.96178011e-15
#  -2.96178011e-15  5.95303344e-15]

# %%
from timeit import default_timer as timer
from matplotlib import pyplot as plt
# store data as an array
X = np.array(alldf)
y = alldf.skin

# use cross_val_predict to generate K-Fold predictions
lm = linear_model.LinearRegression()

# fit a model
model = lm.fit(xtrain, ytrain)
predictions = lm.predict(xval)

## The line / model
plt.scatter(yval, predictions)
plt.xlabel("True Values")
plt.ylabel("Predictions")

print ("Score:", model.score(xval, yval))
# Out:
# Score: 0.5124059794838541
